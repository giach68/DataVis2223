# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Subplots
#
# **Purpose:** Allows you to place multiple charts in a figure.
#
# **matplotlib function:** [``subplot(nrows, ncols, plot_number)``](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.subplot)
#
# * `nrows`: The number of rows in the figure.
#
# * `ncols`: The number of columns in the figure.
#
# * `plot_number`: The placement of the chart (starts at 1).

# %%
plt.figure()

for i in range(1, 7):
    plt.subplot(3, 2, i)
    plt.title(i)
    plt.xticks([])
    plt.yticks([])

plt.tight_layout()

# %%
dist1 = np.random.normal(42, 7, 1000)
dist2 = np.random.normal(59, 3, 1000)

plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.hist(dist1)
plt.title('dist1')

plt.subplot(1, 2, 2)
plt.scatter(dist2, dist1)
plt.xlabel('dist2')
plt.ylabel('dist1')

plt.tight_layout()

# %% [markdown]
# # Small multiples
#
# ### Useful for comparing many categories

# %%
years = np.arange(2010, 2016)

plt.figure()

for category_num in range(1, 17):
    y_vals = np.arange(10, 16) + (np.random.random(6) * category_num / 4.)
    plt.plot(years, y_vals)

plt.ylim(10, 18)
plt.xticks(years, [str(year) for year in years])
# Out:
# ([<matplotlib.axis.XTick at 0x17e8695ccd0>,
#   <matplotlib.axis.XTick at 0x17e8695cca0>,
#   <matplotlib.axis.XTick at 0x17e83a197c0>,
#   <matplotlib.axis.XTick at 0x17e86607fd0>,
#   <matplotlib.axis.XTick at 0x17e8661ca90>,
#   <matplotlib.axis.XTick at 0x17e865bab80>],
#  [Text(2010, 0, '2010'),
#   Text(2011, 0, '2011'),
#   Text(2012, 0, '2012'),
#   Text(2013, 0, '2013'),
#   Text(2014, 0, '2014'),
#   Text(2015, 0, '2015')])

# %% [markdown]
# ### Same chart, same axes, many times

# %%
years = np.arange(2010, 2016)

plt.figure(figsize=(10, 10))

for category_num in range(1, 17):
    plt.subplot(4, 4, category_num)
    y_vals = np.arange(10, 16) + (np.random.random(6) * category_num / 4.)
    plt.plot(years, y_vals)
    plt.ylim(10, 18)
    plt.xticks(years, [str(year) for year in years])
    plt.title('Category {}'.format(category_num))
    
plt.tight_layout()
;
# Out:
# ''

# %% [markdown]
# *more complicated layout*

# %% [markdown]
# <img src="indego-bike-station-usage-patterns-july-aug-2015-flip.png" />

# %%
fig = plt.figure(figsize=(8, 8))
gs = plt.GridSpec(3, 3)
ax1 = fig.add_subplot(gs[0, :])
ax2 = fig.add_subplot(gs[1, :2])
ax3 = fig.add_subplot(gs[1:, 2])
ax4 = fig.add_subplot(gs[2, 0])
ax5 = fig.add_subplot(gs[2, 1])
